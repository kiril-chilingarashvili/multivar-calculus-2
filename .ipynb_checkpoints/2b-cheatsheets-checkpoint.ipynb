# %% [markdown]
# # Unit 2: Introduction to Line Integrals - Part b - Line Integrals

# %% [markdown]
# ## Finding the mass of a thin wire
#
# ### **Problem**:
# ### You have a curve $C$ in the plane, which is the arc of the parabola $y=x^2$ that goes from $(0,0)$ to $(2,4)$.
# ![img](img/img-5-01.png)
#
# ### The curve $C$ is actually a wire with variable density. The linear density of a point $(x,y)$ along the wire is given by $\rho(x,y) = 1+y$ kilograms per meter. Our goal is to find the mass of the wire.
#
# ## **Remark 2.1**
#
# ### What do we mean by **linear density**? When a wire has linear density $\delta$ with units of kilograms per meter, it means that a small piece of the wire of length $l$, with units of meters, has mass $\delta l$ kilograms.
#
# ### You might be more used to seeing density given in dimensions of mass per volume, or mass per length cubed. Here the idea is that the wire is so thin that the cross-sectional area is negligible, so that the mass of a small piece of wire depends only on its length. Therefore, in this thin-wire situation, we can use linear density instead of density, which typically refers to mass per volume.
#
# ### How do we think about the density? It means that the mass of a small piece of the wire near the point $(x,y)$ is equal to the length of that piece of wire multiplied by $\rho(x,y) = 1+y$.
# ## $$ \underbrace{(1+y)}_{\text{kilograms/meter}} \underbrace{ds}_{\text{meters}}  $$
#
# ## **Goal: Find the mass of the wire**
# ### **Plan**:
# ### Cut $C$ into small arcs (representing small pieces of the wire).
# ### 1. Approximate the mass of each arc.
# ### 2. Add them up.
#
# ### In order to cut $C$ into small pieces, we parametrize it!

# %% [markdown]
# ## Find the mass of a small arc
#
# ### Now that we have a parametrization $(x(t), y(t)) = (t,t^2)$ for $0\leq t \leq 2$, we can cut our curve $C$ into small arcs.
# ![img](img/img-5-02.png)
#
# ### Let's zoom in on a small arc from $t=t_0$ to $t=t_0+\Delta t$, for some very small $\Delta t$, and approximate the mass of that arc. As $t$ moves from $t_0$ to $t_0+\Delta t$, it causes $x$ and $y$ to change by small amounts $\Delta x$ and $\Delta y$.
# ![img](img/img-5-03.png)
#
# ### Therefore, the length of this piece is approximately $\displaystyle \sqrt{(\Delta x)^2 + (\Delta y)^2}$. Next, we know that mass is the linear density (which has a dimension of Mass/Length) times the length of the arc (which has a dimension of Length). (Recall that our linear density is given to us as $\rho(x, y) = 1+y$.)
# ## $$ \begin{array} {rcl} \text{Mass} & = & {\color{orange}{\text{(linear density)}}} \cdot {\color{red}{\text{(length of arc)}}} \\ \, & \approx & \displaystyle {\color{orange}{(1+y(t_0))}} \cdot {\color{red}{\sqrt{(\Delta x)^2+(\Delta y)^2}}} \end{array} $$
#
# ### We could stop here. However, we can express everything in terms of $t$.
#
# ### Using our parameterization, we have:
# ## $$ \begin{array} {rcl} x(t) & = & t \\ \Delta x & \approx & x'(t_0)\Delta t = \Delta t \\ y(t) & = & t^2 \\ \Delta y & \approx & y'(t_0) \Delta t = 2 t_0 \Delta t \end{array} $$
#
# ### Therefore the mass of the small arc can be written entirely in terms of its starting $t$-value $t_0$:
# ## $$ \text{Mass of small arc} = (1+t_0^2) \sqrt{1 + (2t_0)^2} \Delta t $$
#
# ### Note that we are making two assumptions in making this approximation for $\Delta t$ small enough.
#
# - ### The first approximation assumes that $\Delta t$ is small enough that the density can be approximated to be $(1+t_0^2)$ on the entire interval $t_0 \leq t \leq t_0 + \Delta t$.
# - ### The second approximation assumes that $\Delta t$ is small enough that the arc length is approximately equal to the straight line hypotenuse whose length is $\displaystyle \sqrt{(\Delta x)^2 +(\Delta y)^2}$ by the pythagorean theorem.

# %% [markdown]
# ## Write total mass as an integral
#
# ### We found the mass of a small arc of our curve $c$, which is parametrized by $(x(t), y(t)) = (t,t^2)$ for $0 \leq t \leq 2$ and has linear density $\rho(x, y) = 1+y$ to be
# ## $$ \text{Mass of small arc at}\, t_0 = (1+t_0^2) \sqrt{1+(2t_0)^2} \Delta t $$
#
# ### We write the total mass by summing up these small pieces, which we write as an integral
# ## $$ \text{Total mass} = \int_{0}^{2} (1+t^2) \sqrt{1+(2t)^2} \mathop{dt} $$
#
# ### **Remark 4.1**
#
# ### **What is $\displaystyle \int_a^b F(t) \mathop{dt}$?**
# ### There are two different ways that we can think about integrals.
# - ### The first way we are introduced to thinking about integral is more geometric. We think of the integral $\displaystyle \int_a^b F(t) \mathop{dt}$ as measuring the area under the curve.
# ![img](img/img-5-04.png)
#
# ### This is true, and it is worth thinking about.
#
# - ### This integral $\displaystyle \int_a^b F(t) \mathop{dt}$ can also be interpreted as the accumulation of $F(t)$ along the interval $a \leq t \leq b$. That is, it also means, cut the interval from $a$ to $b$ into small intervals.
# ![img](img/img-5-05.png)
#
# ### 1. For each small interval, compute $F(t_0) \Delta t$ (where $t_0$ is a point in the small interval, and $\Delta t$ is the length of that interval).
# ![img](img/img-5-06.png)
#
# ### 2. Add them up.
#
# ### It is a little easier to think about these line integrals in the second format, which works more generally. These two approaches are equivalent, and they work for all types of integrals. However, the second approach is the approach that we will be generalizing to different types of integrals throughout this unit and the next.

# %% [markdown]
# ## The concept of a line integral
#
# ### **Understanding $\mathop{ds}$**
#
# ### In the previous example, we had some function defined along a curve, and we “added up" the value of the function along the curve using an integral. This is an example of the more abstract notion of a **line integral**. We think of line integrals as measuring the accumulation of some function along a curve.
#
# ### **Definition 5.1**
#
# ### Given a curve $C$, the **line integral** of a function $f(x,y)$ along $C$ is written as:
# ## $$ \int_C f(x, y) \mathop{ds} $$
#
# ### **This means**:
# ### cut $C$ into short arcs.
# ### 1. For each arc, compute $f(x, y) \cdot \text{(arc length)}$, where $(x,y)$ is the position of the arc.
# ### 2. Add them up.
#
# ### In particular, the integral is the value that this process approaches as the lengths of the short arcs go to zero.
# ![img](img/img-5-07.png)
#
# ### Note that all of the symbols are related to the procedure described above:
# ## $$ \int_C f{\color{orange}{(x, y)}} {\color{blue}{\mathop{ds}}} $$
#
# ### We cut up our curve into small segments of length ${\color{blue}{\mathop{ds}}}$.
#
# ### 1. The point $\color{orange}{(x, y)}}$ lies on the curve $C$, and the function $f$ is evaluated at points $\color{orange}{(x, y)}}$ along the curve.
# ### 2. The integral symbol $\displaystyle \int$ means that we are adding up all of these pieces.
#
# ### **Example 5.2**
# ### If $C$ is a wire, and $f(x, y)$ describes the linear density in units of kg/m at the point $(x, y)$, then
# ## $$ \int_{C} f(x, y) \mathop{ds} = \text{total mass of the wire} $$
#
# ### To compute the integral, we first find a parametrization of $C$ as $(x(t), y(t))$ for $a \leq t \leq b$. Then we can write this integral as
# ## $$ \int_C \underbrace{f(x, y)}_{\text{density}} \underbrace{\mathop{ds}}_{\text{arc length}} = \int_a^b \underbrace{f(x(t), y(t))}_{\text{density}} \underbrace{\sqrt{x'(t)^2+y'(t)^2}\mathop{dt}}_{\text{arc length}} $$
#
# ### **Remark 5.3**
# ### The name **line integral** is a bit of a misnomer. A better term might be path integral or curve integral. However, in our approach to computing the integral along a curve $C$, the approximation technique approximates each small arc as a line. So let the name remind you of how to compute each small arc length $\mathop{ds}$ as the hypotenuse of a small triangle of width $\mathop{dx}$ and height $\mathop{dy}$.
#
# ### **Spoiler: line integrals in 3D**
# ### If we have a 3D curve $C$ and a function $g(x, y, z)$, then we can compute the line integral
# ## $$ \int_C g(x, y, z) \mathop{ds} $$
#
# ## To carry out this computation, parametrize $C$ by $(x(t), y(t), z(t))$ for $a \leq t \leq b$, then
# ## $$ \mathop{ds} = \sqrt{x'(t)^2+y'(t)^2+z'(t)^2} \mathop{dt} $$
#
# ### and we compute the value of the line integral via the single variable integral below:
# ## $$ \int_a^b g(x(t), y(t), z(t)) \sqrt{x'(t)^2+y'(t)^2+z'(t)^2} \mathop{dt} $$
